# %% [markdown]
# # EVALUATION PROJECT 10:- ZOMATO RESTAURANT
# # INTERNSHIP NUMBER:- 66
# # NAME- SUBHAM
# # BATCH - DS2401

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# first convert excel csv file into excel file then use the read_excel fuction
df1a=pd.read_excel('C:/Users/DELL/Downloads/zomato.xlsx')
df1a
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208             False
# 9547        5908749                     False           208             False
# 9548        5915807                     Huqqa           208             False
# 9549        5916112                     False           208             False
# 9550        5927402  Walter's Coffee Roastery           208             False
#
# ...

# %%
pd.set_option('Display.max_columns',None)

# %%
df1a
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208             False
# 9547        5908749                     False           208             False
# 9548        5915807                     Huqqa           208             False
# 9549        5916112                     False           208             False
# 9550        5927402  Walter's Coffee Roastery           208             False
#
# ...

# %%
df1b=pd.read_excel('C:/Users/DELL/Downloads/Country-Code.xlsx')
df1b
# this table represents country name for country code
# country code is given in the first dataframe we can check using this dataframe which country it belongs to
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df1a.shape
# there are 9551 rows and 21 columns present in the dataset
# Out:
# (9551, 21)

# %%
df1a.dtypes
# datatype of each column is right
# most columns are divided into int and object ,only longitude , latitude and aggregate rating columns are of float datatype
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
# numerical columns are :-
# 'Restaurant ID' , 'Country Code ' , 'Longitude' , 'Latitude' , 'Average Cost for two' , 'Price range' , 'Aggregate rating ' ,
# 'Votes'
# categorical columns are:-
# 'Restaurant Name' , 'City' , 'Address' , 'Locality' , 'Locality Verbose' , 'Cuisines' , 'Currency' , 'Has Table booking' ,
# 'Has Online delivery' , 'Is delivering now' , 'Switch to order menu' , 'Rating color' , 'Rating text'

# %%
df1a.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df1a['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Fast Food                                                354
# Chinese                                                  354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1824, dtype: int64

# %% [markdown]
# # FILLING NULL VALUES WITH MODE OF THAT COLUMN

# %%
df1a['Cuisines'].fillna('North Indian',inplace=True)

# %%
df1a.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df1a.info()
# this shows:
# 1) there are 9551 rows and 21 columns
# 2) there are no null values in the dataset(9551 non null values)
# 3) and datatype of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
for i in df1a.columns:
    print(df1a[i].value_counts())
    print('\n')
# this show :
# 1) value counts for each unique value of each column
# 2) length represents total no. of unique values for that column
# 3) for e.g :- for Restaurant Name column ,False is a unique value and it's value count is 103
# Out:
# Restaurant ID
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: count, Length: 9551, dtype: int64
#
#
# Restaurant Name
# False                       103
# Cafe Coffee Day              83
# Domino's Pizza               79
# Subway                       63
# Green Chick Chop             51
#                            ...
# The G.T. Road                 1
# The Darzi Bar & Kitchen       1
# Smoke On Water                1
# Piali - The Curry Bistro      1
# Walter's Coffee Roastery      1
# Name: count, Length: 7355, dtype: int64
#
#
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64
#
#
# City
# New Delhi           5473
# Gurgaon             1118
# ...

# %%
df1a['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# not known                   103
# Cafe Coffee Day              83
# Domino's Pizza               79
# Subway                       63
# Green Chick Chop             51
#                            ...
# The G.T. Road                 1
# The Darzi Bar & Kitchen       1
# Smoke On Water                1
# Piali - The Curry Bistro      1
# Walter's Coffee Roastery      1
# Name: count, Length: 7355, dtype: int64

# %% [markdown]
# # DESCRIPTION OF DATASET

# %%
df1a.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df1a.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df1a = df1a.replace({ False: 'not known'})

# %%
df1a = df1a.replace({'Le Petit Souffle' : 'Le Petit Souffle'})

# %%
for i in df1a.columns:
    if df1a[i].dtypes=='object':
        df1a[i]=df1a[i].astype('object')
    elif df1a[i].dtypes=='int64':
        df1a[i]=df1a[i].astype('int64')
    else:
        df1a[i]=df1a[i].astype('float64')

# %%
df1a
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         not known
# 9547        5908749                 not known           208         not known
# 9548        5915807                     Huqqa           208         not known
# 9549        5916112                 not known           208         not known
# 9550        5927402  Walter's Coffee Roastery           208         not known
#
# ...

# %%
# numerical columns are :-
# 'Restaurant ID' , 'Country Code ' , 'Longitude' , 'Latitude' , 'Average Cost for two' , 'Price range' , 'Aggregate rating ' ,
# 'Votes'

# %%
# 1) all the columns count is 9551 meaning no null value is present in the dataset
# 2) skewness is present in the dataset ,if mean > median (50%)-> right skew and if median > mean -> left skew
#    right skew: 'RestaurantID' , 'Country Code' , 'Aberage cost for two'(highly) , 'Votes'(highly)
#    left skew: 'Longitude' , 'Latitude' , 'Price Range' , 'Aggregate rating'
# 3) outliers are present in the dataset, if there is a jump in the value of 75% and 100% outliers maybe present
#    e.g:-  'Country Code' , 'Longitude'(highly) , 'Latitude' , 'Average cost for two'(highly) , 'Price Range' , 'Votes'(highly)
#
# categorical columns are:-
# 'Restaurant Name' , 'City' , 'Address' , 'Locality' , 'Locality Verbose' , 'Cuisines' , 'Currency' , 'Has Table booking' ,
# 'Has Online delivery' , 'Is delivering now' , 'Switch to order menu' , 'Rating color' , 'Rating text'

# %%
df1a.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df1c=df1a[['Restaurant ID', 'Country Code', 'City',
       'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
       'Average Cost for two', 'Currency', 'Has Table booking',
       'Has Online delivery', 'Is delivering now', 'Switch to order menu',
       'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
       'Votes']]

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df1c.columns:
    if df1c[i].dtypes=='object':
        df1c[i]=OE.fit_transform(df1c[i].values.reshape(-1,1))

# %%
df1d=df1a[['Restaurant Name','Address']]
df1d
# Out:
#                Restaurant Name  \
# 0             Le Petit Souffle
# 1             Izakaya Kikufuji
# 2       Heat - Edsa Shangri-La
# 3                         Ooma
# 4                  Sambo Kojin
# ...                        ...
# 9546               Naml۱ Gurme
# 9547                 not known
# 9548                     Huqqa
# 9549                 not known
# 9550  Walter's Coffee Roastery
#
#                                                 Address
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546                                          not known
# 9547                                          not known
# 9548                                          not known
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df1d.columns:
    if df1d[i].dtypes=='object':
        df1d[i]=OE.fit_transform(df1d[i].values.reshape(-1,1))
# it's not converting retaurant name and address to integer so i'm only taking  the other columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:173, in _unique_python(values, return_inverse, return_counts)
#     171 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 173 uniques = sorted(uniques_set)
#     174 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[133], line 5
#       3 for i in df1d.columns:
#       4     if df1d[i].dtypes=='object':
# ----> 5         df1d[i]=OE.fit_transform(df1d[i].values.reshape(-1,1))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
# ...

# %%
df1c
# Out:
#       Restaurant ID  Country Code   City  Locality  Locality Verbose  \
# 0           6317637           162   72.0     168.0             163.0
# 1           6304287           162   72.0     580.0             578.0
# 2           6300002           162   74.0     304.0             304.0
# 3           6318506           162   74.0     845.0             845.0
# 4           6314302           162   74.0     845.0             845.0
# ...             ...           ...    ...       ...               ...
# 9546        5915730           208  138.0    1185.0            1223.0
# 9547        5908749           208  138.0    1185.0            1223.0
# 9548        5915807           208  138.0    1185.0            1223.0
# 9549        5916112           208  138.0    1185.0            1223.0
# 9550        5927402           208  138.0     656.0            1223.0
#
#        Longitude   Latitude  Cuisines  Average Cost for two  Currency  \
# ...

# %% [markdown]
# # CHECKING SKEWNESS

# %%
df1c.columns
# Out:
# Index(['Restaurant ID', 'Country Code', 'City', 'Locality', 'Locality Verbose',
#        'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
a=['Restaurant ID', 'Country Code', 'City', 'Locality', 'Locality Verbose',
       'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
       'Has Table booking', 'Has Online delivery', 'Is delivering now',
       'Switch to order menu', 'Price range', 'Aggregate rating']
b=['Rating color', 'Rating text', 'Votes']

# %%
#for checking skewness of multiple columns at the same time
plt.figure(figsize=(20,25))
p=1
for i in a:
    if p<=16:
        ax=plt.subplot(4,4,p)
        sns.distplot(df1c[i])
    p+=1

# %%
#for checking skewness of multiple columns at the same time
plt.figure(figsize=(20,25))
p=1
for i in b:
    if p<=16:
        ax=plt.subplot(4,4,p)
        sns.distplot(df1c[i])
    p+=1

# %%
# we can see from the displot from above that skewness is present in some of the columns
# right skewed :- 'ResutaurantID' , 'Country Code' , 'Average cost for two'(highly) , 'Price range' 'Votes'(highly)
# left skewed :- 'Longitude'(highly) , 'Latitude'(highly) , 'Aggregate rating' 
# categorical data is:-
# 'Restaurant Name' , 'City' , 'Address' , 'Locality' , 'Locality Verbose' , 'Cuisines' , 'Currency' , 'Has Table booking' ,
# 'Has Online delivery' , 'Is delivering now' , 'Switch to order menu' , 'Rating color' , 'Rating text'
# it's better to leave categorical columns

# %%
df=df1a[['Restaurant ID' , 'Country Code' , 'Longitude' , 'Latitude' , 'Average Cost for two' , 'Price range' , 'Aggregate rating',
   'Votes']]
df
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9546        5915730           208   28.977392  41.022793
# 9547        5908749           208   29.041297  41.009847
# 9548        5915807           208   29.034640  41.055817
# 9549        5916112           208   29.036019  41.057979
# 9550        5927402           208   29.026016  40.984776
#
#       Average Cost for two  Price range  Aggregate rating  Votes
# 0                     1100            3               4.8    314
# 1                     1200            3               4.5    591
# 2                     4000            4               4.4    270
# ...

# %%
#we can check numerical value of skewness too
# acceptable range of skewness is +0.5 to -0.5
df1c.skew()
# Positive value means the distribution is skewed to the right.
# Negative value means the distribution is skewed to the left.
# 0 means perfect normal distribution. The bell shaped curve.
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# City                    -1.117681
# Locality                -0.245552
# Locality Verbose        -0.171864
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.307257
# Average Cost for two    35.477915
# Currency                 3.516668
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %%
#removing skewness using cuberoot method for right skewed data and square transform for left skewed data
# these are the columns which have values more or less than +0.5 and -0.5 resp.
# df1c['Country Code']=np.cbrt(df1c['Country Code'])
## df1c['Longitude']=np.square(df1c['Longitude'])
df1c['Latitude']=np.square(df1c['Latitude'])
# df['Average Cost for two']=np.cbrt(df1c['Average Cost for two'])
df1c['Price range']=np.cbrt(df1c['Price range'])
df1c['Aggregate rating']=np.square(df1c['Aggregate rating'])
df1c['Votes']=np.cbrt(df1c['Votes'])
# 'Average Cost for two' is target label so it's better to not remove it's skewness
# 'Country Code' contains country codes so removing skewness from this should also be avoided
# longitude skewness is increased in the positive value so it's better to not removed skewness from this
# latitude decreases the skewness a litttle but it's positive value is still big(1.766)
# votes skewness will increase in the negative side if we do more so let's leave it at that as well

# %%
df1c.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# City                    -1.117681
# Locality                -0.245552
# Locality Verbose        -0.171864
# Longitude               -2.807328
# Latitude                 1.766312
# Cuisines                -0.307257
# Average Cost for two    35.477915
# Currency                 3.516668
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.495755
# Aggregate rating        -0.208868
# Rating color             0.046009
# Rating text              0.431408
# Votes                    1.204920
# dtype: float64

# %% [markdown]
# # CHECKING FOR OUTLIERS

# %%
#check for outliers using boxplot
# for multiple boxplot visualization
plt.figure(figsize=(20,25))
p=1
for i in a :
    if p<=16:
        ax=plt.subplot(4,4,p)
        sns.boxplot(df1c[i])
        plt.xlabel(i)
    p+=1

# %%
#check for outliers using boxplot
# for multiple boxplot visualization
plt.figure(figsize=(20,25))
p=1
for i in b :
    if p<=16:
        ax=plt.subplot(4,4,p)
        sns.boxplot(df1c[i])
        plt.xlabel(i)
    p+=1

# %%
# we can see from boxplots that outliers are present in the dataset
# outliers are present in :- 'Country Code' , 'Longitude' , 'Latitude' , 'Average cost for living' , 'Votes' 

## categorical data is:-
# 'Restaurant Name' , 'City' , 'Address' , 'Locality' , 'Locality Verbose' , 'Cuisines' , 'Currency' , 'Has Table booking' ,
# 'Has Online delivery' , 'Is delivering now' , 'Switch to order menu' , 'Rating color' , 'Rating text'
# it's better to leave categorical columns

#'City' , 'Currency' , 'Has Table booking' , 'Is delivering now' shows outliers

# %%
df1c.columns
# Out:
# Index(['Restaurant ID', 'Country Code', 'City', 'Locality', 'Locality Verbose',
#        'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
#removing outliers
from scipy.stats import zscore
d=df1c[['Restaurant ID', 'Country Code', 'City', 'Locality', 'Locality Verbose',
       'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
       'Has Table booking', 'Has Online delivery', 'Is delivering now',
       'Switch to order menu', 'Price range', 'Aggregate rating',
       'Rating color', 'Rating text', 'Votes']]
z=np.abs(zscore(d))
z
# Out:
#       Restaurant ID  Country Code      City  Locality  Locality Verbose  \
# 0          0.310940      2.531111  0.241971  1.543761          1.535084
# 1          0.312458      2.531111  0.241971  0.219455          0.252434
# 2          0.312946      2.531111  0.155599  1.106611          1.099293
# 3          0.310841      2.531111  0.155599  0.632344          0.572789
# 4          0.311319      2.531111  0.155599  0.632344          0.572789
# ...             ...           ...       ...       ...               ...
# 9546       0.356658      3.341718  2.608317  1.725218          1.741082
# 9547       0.357452      3.341718  2.608317  1.725218          1.741082
# 9548       0.356649      3.341718  2.608317  1.725218          1.741082
# 9549       0.356614      3.341718  2.608317  1.725218          1.741082
# 9550       0.355330      3.341718  2.608317  0.024835          1.741082
#
#       Longitude  Latitude  Cuisines  Average Cost for two  Currency  \
# ...

# %%
# above table shows z score of all columns 
# z score less than 3 contains 99.7% data
np.where(z>3)
#z score greater than 3 meaning outliers
# these values represent outliers
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64),
#  array([9, 9, 9, ..., 9, 1, 9], dtype=int64))

# %%
import numpy as np  
outlier_indices = np.where(z > 3)[0]
df1e = df1c.drop(outlier_indices)
print("Original DataFrame Shape:", df1c.shape)
print("DataFrame Shape after Removing Outliers:", df1e.shape)
# 961 rows are removed
# Out:
# Original DataFrame Shape: (9551, 19)
# DataFrame Shape after Removing Outliers: (8590, 19)

# %%
9551-8590
# 961 rows are removed
# Out:
# 961

# %%
import numpy as np  
outlier_indices = np.where(z > 3)[1]
df1f = df1c.drop(outlier_indices)
print("Original DataFrame Shape:", df1c.shape)
print("DataFrame Shape after Removing Outliers:", df1f.shape)
# 8 rows are removed
# Out:
# Original DataFrame Shape: (9551, 19)
# DataFrame Shape after Removing Outliers: (9543, 19)

# %%
9551-9543
# 8 rows are removed
# Out:
# 8

# %%
# 961 rows have been deleted
#this is percentage loss of data. max data that we can afford to lose is 10%
# since our value is 10.06% we lose 10.06% data which is within 10% range
#we cannot lose too much data as some data might be essential for model building
(df1c.shape[0]-df1e.shape[0])/(df1c.shape[0])*100
# Out:
# 10.061773636268454

# %% [markdown]
# # CHECK FOR CORRELATION AND MULTICOLLINEARITY

# %%
df1e.corr()
# Out:
#                       Restaurant ID  Country Code      City  Locality  \
# Restaurant ID              1.000000      0.032981 -0.012095  0.091635
# Country Code               0.032981      1.000000  0.012768 -0.011941
# City                      -0.012095      0.012768  1.000000 -0.024902
# Locality                   0.091635     -0.011941 -0.024902  1.000000
# Locality Verbose           0.089925      0.003763 -0.001673  0.986717
# Longitude                 -0.121385      0.155454 -0.100887 -0.013779
# Latitude                  -0.121310      0.029744  0.032558  0.012958
# Cuisines                  -0.054895     -0.042492  0.015358 -0.012940
# Average Cost for two      -0.143690     -0.088879 -0.067013 -0.047405
# Currency                  -0.011084      0.185799 -0.231870  0.015397
# Has Table booking         -0.094682     -0.037955 -0.024684 -0.071693
# Has Online delivery       -0.064628     -0.067570 -0.032254 -0.047541
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df1e.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
# heat map for new dataset
# Out:
# <Axes: >

# %%
# 1) we can see from the above data that most of the column are not much correlated with each other
# 2) there is some correlation b/w columns which can cause multicollinearity like 'Longitude' and 'Latitude'(0.79) ,
#    'Average cost for two' and 'Price range'(0.74) , 'Average rating' and 'votes'(0.78) , 'Price range' and 
#    'Has Table booking'(0.53) , 'price range' and 'votes'(0.52) , 'Average Cost for booking' and 'Has table booking'(0.62) etc
# 3)'Average cost for booking' which is label/target have also low correlation to other columns except for 
#    Has table booking(0.62) and price range(0.74)

# %%
x=df1e.drop(['Average Cost for two'],axis=1)
x
# Out:
#       Restaurant ID  Country Code   City  Locality  Locality Verbose  \
# 22          6600681            30  138.0      66.0            1223.0
# 23          6601005            30  138.0      66.0            1223.0
# 24          6600292            30  138.0      66.0            1223.0
# 25          6600441            30  138.0      66.0            1223.0
# 26          6600970            30  138.0      67.0            1223.0
# ...             ...           ...    ...       ...               ...
# 9432        6201972           166   37.0    1045.0            1081.0
# 9433        6201130           166   37.0    1068.0            1104.0
# 9434       18261203           166   37.0    1074.0            1110.0
# 9435        6201360           166   37.0    1097.0            1135.0
# 9436       18318801           166   37.0    1097.0            1135.0
#
#       Longitude    Latitude  Cuisines  Currency  Has Table booking  \
# 22   -47.881789  248.508163     851.0       1.0                0.0
# ...

# %%
y=df1e['Average Cost for two']
y
# Out:
# 22       55
# 23       30
# 24       45
# 25       60
# 26       50
#        ...
# 9432    200
# 9433    550
# 9434    445
# 9435    400
# 9436    160
# Name: Average Cost for two, Length: 8590, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
df2=pd.DataFrame(s.fit_transform(x),columns=x.columns)
df2
# Out:
#       Restaurant ID  Country Code      City  Locality  Locality Verbose  \
# 0         -0.247936      1.740978  3.118242 -1.978403          1.754190
# 1         -0.247900      1.740978  3.118242 -1.978403          1.754190
# 2         -0.247980      1.740978  3.118242 -1.978403          1.754190
# 3         -0.247963      1.740978  3.118242 -1.978403          1.754190
# 4         -0.247904      1.740978  3.118242 -1.975082          1.754190
# ...             ...           ...       ...       ...               ...
# 8585      -0.292609     10.424204 -2.286362  1.272997          1.301139
# 8586      -0.292704     10.424204 -2.286362  1.349383          1.374520
# 8587       1.058563     10.424204 -2.286362  1.369310          1.393664
# 8588      -0.292678     10.424204 -2.286362  1.445696          1.473426
# 8589       1.065017     10.424204 -2.286362  1.445696          1.473426
#
#       Longitude  Latitude  Cuisines  Currency  Has Table booking  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(df2.values,i) for i in range(len(df2.columns))]
vif['features']=df2.columns
vif
# Out:
#     VIF values              features
# 0     1.438927         Restaurant ID
# 1     1.271371          Country Code
# 2     1.106594                  City
# 3    51.856896              Locality
# 4    52.046436      Locality Verbose
# 5     3.729928             Longitude
# 6     3.284775              Latitude
# 7     1.031895              Cuisines
# 8     1.483497              Currency
# 9     1.500636     Has Table booking
# 10    1.203020   Has Online delivery
# 11         NaN     Is delivering now
# 12         NaN  Switch to order menu
# 13    1.929423           Price range
# 14    3.215535      Aggregate rating
# 15    1.219926          Rating color
# 16    1.336181           Rating text
# 17    4.098911                 Votes

# %%
# we can see that vif values for all columns are low meaning their is no or less multicollinearity
# except for 'Locality' and "Locality verbose"
# but since we have already lost so much data let's not remove any column

# %% [markdown]
# # MODEL BUILDING FOR AVERAGE COST FOR TWO

# %%
# i'm taking this as regression as cost can be change depending on different factors like place , location. so it cannot be 
# exactly 1200 etc. so regression is used instead of classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor 
from sklearn.tree import DecisionTreeRegressor 
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.linear_model import Lasso  , Ridge

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr= LinearRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    acc=r2_score(y_test,predlr)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('max r2 is',maxaccu,'at random state',maxrs)
# Out:
# max r2 is 0.7301652277335164 at random state 114

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=114)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
pred_train_lr=lr.predict(x_train)
print(lr)
print('r2 score',r2_score(y_test,predlr))
print('r2 score on training data',r2_score(y_train,pred_train_lr))
print('mean absloute error',mean_absolute_error(y_test,predlr))
print('mean squared error',mean_squared_error(y_test,predlr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# LinearRegression()
# r2 score 0.7301652277335164
# r2 score on training data 0.6553887240217962
# mean absloute error 181.22278039487585
# mean squared error 78630.74654832247
# root mean squared error 280.4117446690179

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predrfr=rfr.predict(x_test)
pred_train_rfr=rfr.predict(x_train)
print(rfr)
print('r2 score',r2_score(y_test,predrfr))
print('r2 score on training data',r2_score(y_train,pred_train_rfr))
print('mean absloute error',mean_absolute_error(y_test,predrfr))
print('mean squared error',mean_squared_error(y_test,predrfr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predrfr)))
# Out:
# RandomForestRegressor()
# r2 score 0.853664949076585
# r2 score on training data 0.9840942279104524
# mean absloute error 105.66674039580906
# mean squared error 42642.518618509894
# root mean squared error 206.50065040699

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
pred_train_knn=knn.predict(x_train)
print(knn)
print('r2 score',r2_score(y_test,predknn))
print('r2 score on training data',r2_score(y_train,pred_train_knn))
print('mean absloute error',mean_absolute_error(y_test,predknn))
print('mean squared error',mean_squared_error(y_test,predknn))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predknn)))
# Out:
# KNeighborsRegressor()
# r2 score 0.02955361127824707
# r2 score on training data 0.3930555876130657
# mean absloute error 344.2467986030268
# mean squared error 282791.29257275903
# root mean squared error 531.7812450366777

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
preddtr=dtr.predict(x_test)
pred_train_dtr=dtr.predict(x_train)
print(dtr)
print('r2 score',r2_score(y_test,preddtr))
print('r2 score on training data',r2_score(y_train,pred_train_dtr))
print('mean absloute error',mean_absolute_error(y_test,preddtr))
print('mean squared error',mean_squared_error(y_test,preddtr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,preddtr)))
# Out:
# DecisionTreeRegressor()
# r2 score 0.6708924981840015
# r2 score on training data 1.0
# mean absloute error 135.6814124951494
# mean squared error 95903.01629802096
# root mean squared error 309.68212137290226

# %%
l=Lasso()
l.fit(x_train,y_train)
predl=l.predict(x_test)
pred_train_l=l.predict(x_train)
print(l)
print('r2 score',r2_score(y_test,predl))
print('r2 score on training data',r2_score(y_train,pred_train_l))
print('mean absloute error',mean_absolute_error(y_test,predl))
print('mean squared error',mean_squared_error(y_test,predl))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predl)))
# Out:
# Lasso()
# r2 score 0.7316690678671625
# r2 score on training data 0.6552163610852746
# mean absloute error 179.0892730423202
# mean squared error 78192.5225514495
# root mean squared error 279.6292591118631

# %%
r=Ridge()
r.fit(x_train,y_train)
predr=r.predict(x_test)
pred_train_r=r.predict(x_train)
print(r)
print('r2 score',r2_score(y_test,predr))
print('r2 score on training data',r2_score(y_train,pred_train_r))
print('mean absloute error',mean_absolute_error(y_test,predr))
print('mean squared error',mean_squared_error(y_test,predr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predr)))
# Out:
# Ridge()
# r2 score 0.7305989038266791
# r2 score on training data 0.6553732224701525
# mean absloute error 180.47143253785677
# mean squared error 78504.37189809071
# root mean squared error 280.18631640051717

# %%
from sklearn.model_selection import cross_val_score 
cvs=cross_val_score
lrscore=cvs(lr,x,y,scoring='r2')
print(lrscore)
print(lrscore.mean())
print('difference b/w r2 score and cross validation score',(r2_score(y_test,predlr)-lrscore.mean())*100)
# Out:
# [ 0.15422027  0.69643881  0.68136961  0.57860832 -0.63199775]
# 0.2957278479619565
# difference b/w r2 score and cross validation score 43.44373797715599

# %%
from sklearn.model_selection import cross_val_score 
cvs=cross_val_score
rfrscore=cvs(rfr,x,y,scoring='r2')
print(rfrscore)
print(rfrscore.mean())
print('difference b/w r2 score and cross validation score',(r2_score(y_test,predrfr)-rfrscore.mean())*100)
# Out:
# [0.63420227 0.85587206 0.82286146 0.8423657  0.52704189]
# 0.736468675423719
# difference b/w r2 score and cross validation score 11.7196273652866

# %%
from sklearn.model_selection import cross_val_score 
cvs=cross_val_score
knnscore=cvs(knn,x,y,scoring='r2')
print(knnscore)
print(knnscore.mean())
print('difference b/w r2 score and cross validation score',(r2_score(y_test,predknn)-knnscore.mean())*100)
# Out:
# [-0.22366619 -0.1031492  -0.15442524  0.07631903 -0.9344917 ]
# -0.26788266052281695
# difference b/w r2 score and cross validation score 29.7436271801064

# %%
from sklearn.model_selection import cross_val_score 
cvs=cross_val_score
dtrscore=cvs(dtr,x,y,scoring='r2')
print(dtrscore)
print(dtrscore.mean())
print('difference b/w r2 score and cross validation score',(r2_score(y_test,preddtr)-dtrscore.mean())*100)
# Out:
# [0.1901466  0.6684227  0.51379237 0.68089317 0.30013185]
# 0.47067733738914785
# difference b/w r2 score and cross validation score 20.02151607948537

# %%
from sklearn.model_selection import cross_val_score 
cvs=cross_val_score
lscore=cvs(l,x,y,scoring='r2')
print(lscore)
print(lscore.mean())
print('difference b/w r2 score and cross validation score',(r2_score(y_test,predl)-lscore.mean())*100)
# Out:
# [ 0.32874084  0.69637799  0.6830669   0.57390582 -0.44321441]
# 0.36777542840735605
# difference b/w r2 score and cross validation score 36.38936394598064

# %%
from sklearn.model_selection import cross_val_score 
cvs=cross_val_score
rscore=cvs(r,x,y,scoring='r2')
print(rscore)
print(rscore.mean())
print('difference b/w r2 score and cross validation score',(r2_score(y_test,predr)-rscore.mean())*100)
# Out:
# [ 0.17235914  0.69628399  0.68166577  0.57786801 -0.61120347]
# 0.3033946891561226
# difference b/w r2 score and cross validation score 42.72042146705565

# %%
#                                      lr      rfr      knn       dtr      l       r
# r2 score(%)                        73.01    85.36    2.955     67.08   73.16   73.05
# on training data                   65.55    98.40    39.30     100     65.52   65.53
# MAE                                181.2    105.6    344.2     135.68  179.08  180.47
# MSE                                78630.7  42642.5  282791.2  95903.0 78129.5 78504.3
# RMSE                               280.4    206.5    531.78    309.68  279.6   280.1
# cvs score(%)                       29.57    73.64    -0.26     47.06   36.77   30.33
# difference b/w r2 and cvs score(%) 43.44    11.71    29.74     20.02   36.38   42.72

# %%
# we can see from the above results that rfr is the best model for this as it's r2 score is highest and its MAE,MSE and RMSE
# are low compared to others and it's cvs score is also high and difference b/w cvs and r2 score is less
# other model can be made from dtr its r2 score is 67.08 which is best after rfr
# in dtr we can see that its accuracy on training data is 100% but on test data it's 67.08% so overfitting can be seen in this 
# case to some extent
# whole data has lot of errors as none of the r2 score reaches above 85%
# rfr and knn also has overfitting as the values on training data and r2 score differ mostly
# MAE , MSE and RMSE values of all model's are very high meaning there is a lot of error present in the data

# %% [markdown]
# # SAVING THE MODEL AND LOADING THE MODEL AND PREDICTING BASED ON THE MODEL

# %%
# saving the model and loading the model and preidicting based on the model
import joblib
joblib.dump(rfr ,'Zomato Restaurant average cost for two prediction')
# Out:
# ['Zomato Restaurant average cost for two prediction']

# %%
model=joblib.load('Zomato Restaurant average cost for two prediction')
prediction=model.predict(x_test)
prediction
# Out:
# array([1252. , 1418. ,  206. , ..., 1629.5,  317. , 2538. ])

# %%
y_test
# Out:
# 7448    1200
# 2971    1200
# 3187     200
# 7682     300
# 6461    1200
#         ...
# 8530     250
# 5423     200
# 9260    1700
# 3900     400
# 1446    3000
# Name: Average Cost for two, Length: 2577, dtype: int64

# %%
# we can see that real values and predicted values are somewhat close it wo

# %% [markdown]
# #  FOR PRICE RANGE

# %%
# most of the things done for previous one is same for this as well so i'm doing the important parts

# %%
# first convert excel csv file into excel file then use the read_excel fuction
df1a=pd.read_excel('C:/Users/DELL/Downloads/zomato.xlsx')
df1a
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208             False
# 9547        5908749                     False           208             False
# 9548        5915807                     Huqqa           208             False
# 9549        5916112                     False           208             False
# 9550        5927402  Walter's Coffee Roastery           208             False
#
# ...

# %% [markdown]
# # FILLING NULL VALUES

# %%
df1a['Cuisines'].fillna('North Indian',inplace=True)

# %%
df1a.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df1a = df1a.replace({ False: 'not known'})

# %%
df1c=df1a[['Restaurant ID', 'Country Code', 'City',
       'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
       'Average Cost for two', 'Currency', 'Has Table booking',
       'Has Online delivery', 'Is delivering now', 'Switch to order menu',
       'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
       'Votes']]

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df1c.columns:
    if df1c[i].dtypes=='object':
        df1c[i]=OE.fit_transform(df1c[i].values.reshape(-1,1))

# %%
df1c.describe()
# Out:
#        Restaurant ID  Country Code         City     Locality  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    77.602974   648.273793
# std     8.791521e+06     56.750546    23.156763   311.122668
# min     5.300000e+01      1.000000     0.000000     0.000000
# 25%     3.019625e+05      1.000000    83.000000   375.000000
# 50%     6.004089e+06      1.000000    87.000000   682.000000
# 75%     1.835229e+07      1.000000    87.000000   904.000000
# max     1.850065e+07    216.000000   138.000000  1185.000000
#
#        Locality Verbose    Longitude     Latitude     Cuisines  \
# count       9551.000000  9551.000000  9551.000000  9551.000000
# mean         659.674903    64.126574    25.854381   988.486441
# std          323.565852    41.467058    11.007935   513.461502
# min            0.000000  -157.948486   -41.330428     0.000000
# 25%          375.000000    77.081343    28.478713   497.000000
# ...

# %%
# 1) all the columns count is 9551 meaning no null value is present in the dataset
# 2) skewness is present in the dataset ,if mean > median (50%)-> right skew and if median > mean -> left skew
#    right skew: 'RestaurantID' , 'Country Code' , 'Aberage cost for two'(highly) , 'Votes'(highly)
#    left skew: 'Longitude' , 'Latitude' , 'Price Range' , 'Aggregate rating'
# 3) outliers are present in the dataset, if there is a jump in the value of 75% and 100% outliers maybe present
#    e.g:-  'Country Code' , 'Longitude'(highly) , 'Latitude' , 'Average cost for two'(highly) , 'Price Range' , 'Votes'(highly)
#
# categorical columns are:-
# 'Restaurant Name' , 'City' , 'Address' , 'Locality' , 'Locality Verbose' , 'Cuisines' , 'Currency' , 'Has Table booking' ,
# 'Has Online delivery' , 'Is delivering now' , 'Switch to order menu' , 'Rating color' , 'Rating text'

# same as before

# %% [markdown]
# # CHECKING AND REMOVING SKEWNESS

# %%
df1c.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# City                    -1.117681
# Locality                -0.245552
# Locality Verbose        -0.171864
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.307257
# Average Cost for two    35.477915
# Currency                 3.516668
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %%
#removing skewness using cuberoot method for right skewed data and square transform for left skewed data
# these are the columns which have values more or less than +0.5 and -0.5 resp.
# df1c['Country Code']=np.cbrt(df1c['Country Code'])
## df1c['Longitude']=np.square(df1c['Longitude'])
df1c['Latitude']=np.square(df1c['Latitude'])
df1c['Average Cost for two']=np.cbrt(df1c['Average Cost for two'])
# df1c['Price range']=np.cbrt(df1c['Price range'])
df1c['Aggregate rating']=np.square(df1c['Aggregate rating'])
df1c['Votes']=np.cbrt(df1c['Votes'])
# 'Price range' is target label so it's better to not remove it's skewness
#others are same as before

# %%
df1c.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# City                    -1.117681
# Locality                -0.245552
# Locality Verbose        -0.171864
# Longitude               -2.807328
# Latitude                 1.766312
# Cuisines                -0.307257
# Average Cost for two     9.626632
# Currency                 3.516668
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.208868
# Rating color             0.046009
# Rating text              0.431408
# Votes                    1.204920
# dtype: float64

# %%
df1c['Average Cost for two']=np.cbrt(df1c['Average Cost for two'])

# %%
df1c.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# City                    -1.117681
# Locality                -0.245552
# Locality Verbose        -0.171864
# Longitude               -2.807328
# Latitude                 1.766312
# Cuisines                -0.307257
# Average Cost for two     0.023352
# Currency                 3.516668
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.208868
# Rating color             0.046009
# Rating text              0.431408
# Votes                    1.204920
# dtype: float64

# %% [markdown]
# # CHECKING AND REMOVING OUTLIERS

# %%
#removing outliers
from scipy.stats import zscore
d=df1c[['Restaurant ID', 'Country Code', 'City', 'Locality', 'Locality Verbose',
       'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
       'Has Table booking', 'Has Online delivery', 'Is delivering now',
       'Switch to order menu', 'Price range', 'Aggregate rating',
       'Rating color', 'Rating text', 'Votes']]
z=np.abs(zscore(d))
z
# Out:
#       Restaurant ID  Country Code      City  Locality  Locality Verbose  \
# 0          0.310940      2.531111  0.241971  1.543761          1.535084
# 1          0.312458      2.531111  0.241971  0.219455          0.252434
# 2          0.312946      2.531111  0.155599  1.106611          1.099293
# 3          0.310841      2.531111  0.155599  0.632344          0.572789
# 4          0.311319      2.531111  0.155599  0.632344          0.572789
# ...             ...           ...       ...       ...               ...
# 9546       0.356658      3.341718  2.608317  1.725218          1.741082
# 9547       0.357452      3.341718  2.608317  1.725218          1.741082
# 9548       0.356649      3.341718  2.608317  1.725218          1.741082
# 9549       0.356614      3.341718  2.608317  1.725218          1.741082
# 9550       0.355330      3.341718  2.608317  0.024835          1.741082
#
#       Longitude  Latitude  Cuisines  Average Cost for two  Currency  \
# ...

# %%
# above table shows z score of all columns 
# z score less than 3 contains 99.7% data
np.where(z>3)
#z score greater than 3 meaning outliers
# these values represent outliers
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64),
#  array([9, 9, 9, ..., 9, 1, 9], dtype=int64))

# %%
import numpy as np  
outlier_indices = np.where(z > 3)[0]
df1e = df1c.drop(outlier_indices)
print("Original DataFrame Shape:", df1c.shape)
print("DataFrame Shape after Removing Outliers:", df1e.shape)
# 967 rows are removed
# Out:
# Original DataFrame Shape: (9551, 19)
# DataFrame Shape after Removing Outliers: (8584, 19)

# %%
9551-8584
# Out:
# 967

# %%
# 961 rows have been deleted
#this is percentage loss of data. max data that we can afford to lose is 10%
# since our value is 10.12% we lose 10.12% data which is within 10% range
#we cannot lose too much data as some data might be essential for model building
(df1c.shape[0]-df1e.shape[0])/(df1c.shape[0])*100
# Out:
# 10.124594283321118

# %% [markdown]
# # CHECKING FOR CORRELATION AND MULTICOLLINEARITY

# %%
df1e.corr()
# Out:
#                       Restaurant ID  Country Code      City  Locality  \
# Restaurant ID              1.000000      0.033003 -0.011878  0.091667
# Country Code               0.033003      1.000000  0.012797 -0.011937
# City                      -0.011878      0.012797  1.000000 -0.025076
# Locality                   0.091667     -0.011937 -0.025076  1.000000
# Locality Verbose           0.089961      0.003772 -0.001844  0.986709
# Longitude                 -0.121794      0.155537 -0.100079 -0.014379
# Latitude                  -0.121641      0.029724  0.033935  0.012524
# Cuisines                  -0.054509     -0.042532  0.014820 -0.012571
# Average Cost for two      -0.136181     -0.203840 -0.105227 -0.076911
# Currency                  -0.011091      0.185803 -0.232168  0.015399
# Has Table booking         -0.094365     -0.037962 -0.024820 -0.072202
# Has Online delivery       -0.064591     -0.067626 -0.032228 -0.047520
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df1e.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
# heat map for new dataset
# Out:
# <Axes: >

# %%
x=df1e.drop(['Price range'],axis=1)
x
# Out:
#       Restaurant ID  Country Code   City  Locality  Locality Verbose  \
# 22          6600681            30  138.0      66.0            1223.0
# 23          6601005            30  138.0      66.0            1223.0
# 24          6600292            30  138.0      66.0            1223.0
# 25          6600441            30  138.0      66.0            1223.0
# 26          6600970            30  138.0      67.0            1223.0
# ...             ...           ...    ...       ...               ...
# 9432        6201972           166   37.0    1045.0            1081.0
# 9433        6201130           166   37.0    1068.0            1104.0
# 9434       18261203           166   37.0    1074.0            1110.0
# 9435        6201360           166   37.0    1097.0            1135.0
# 9436       18318801           166   37.0    1097.0            1135.0
#
#       Longitude    Latitude  Cuisines  Average Cost for two  Currency  \
# ...

# %%
y=df1e['Price range']
y
# Out:
# 22      2
# 23      1
# 24      2
# 25      3
# 26      2
#        ..
# 9432    4
# 9433    4
# 9434    4
# 9435    4
# 9436    4
# Name: Price range, Length: 8584, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
df2=pd.DataFrame(s.fit_transform(x),columns=x.columns)
df2
# Out:
#       Restaurant ID  Country Code      City  Locality  Locality Verbose  \
# 0         -0.247818      1.740301  3.121217 -1.978237          1.754181
# 1         -0.247782      1.740301  3.121217 -1.978237          1.754181
# 2         -0.247861      1.740301  3.121217 -1.978237          1.754181
# 3         -0.247845      1.740301  3.121217 -1.978237          1.754181
# 4         -0.247786      1.740301  3.121217 -1.974916          1.754181
# ...             ...           ...       ...       ...               ...
# 8579      -0.292489     10.420531 -2.288341  1.273001          1.301148
# 8580      -0.292583     10.420531 -2.288341  1.349383          1.374527
# 8581       1.058620     10.420531 -2.288341  1.369309          1.393669
# 8582      -0.292558     10.420531 -2.288341  1.445692          1.473428
# 8583       1.065073     10.420531 -2.288341  1.445692          1.473428
#
#       Longitude  Latitude  Cuisines  Average Cost for two  Currency  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(df2.values,i) for i in range(len(df2.columns))]
vif['features']=df2.columns
vif
# Out:
#     VIF values              features
# 0     1.444985         Restaurant ID
# 1     1.317293          Country Code
# 2     1.105080                  City
# 3    51.805792              Locality
# 4    51.991583      Locality Verbose
# 5     3.727247             Longitude
# 6     3.292578              Latitude
# 7     1.029791              Cuisines
# 8     2.020813  Average Cost for two
# 9     1.494289              Currency
# 10    1.584987     Has Table booking
# 11    1.206527   Has Online delivery
# 12         NaN     Is delivering now
# 13         NaN  Switch to order menu
# 14    3.202547      Aggregate rating
# 15    1.220376          Rating color
# 16    1.331258           Rating text
# 17    4.119517                 Votes

# %%
# we can see that vif values for all columns are low meaning their is no or less multicollinearity
# except for 'Locality' and "Locality verbose"
# but since we have already lost so much data let's not remove any column

# %% [markdown]
# # EQUATING THE DATA

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
x1,y1=sm.fit_resample(x,y)

# %%
x1
# Out:
#        Restaurant ID  Country Code        City    Locality  Locality Verbose  \
# 0            6600681            30  138.000000   66.000000       1223.000000
# 1            6601005            30  138.000000   66.000000       1223.000000
# 2            6600292            30  138.000000   66.000000       1223.000000
# 3            6600441            30  138.000000   66.000000       1223.000000
# 4            6600970            30  138.000000   67.000000       1223.000000
# ...              ...           ...         ...         ...               ...
# 17099           3325             1   87.000000  427.570493        427.023950
# 17100         310459             1   66.189776  231.072037        231.072037
# 17101           3373             1   87.000000  556.725141        555.233087
# 17102         306154             1   50.478509  266.126495        267.527188
# 17103         307510             1   58.262172  555.275380        553.031638
#
# ...

# %%
y1.value_counts()
# Out:
# Price range
# 2    4276
# 1    4276
# 3    4276
# 4    4276
# Name: count, dtype: int64

# %% [markdown]
# # MODEL BUILDING FOR PRICE RANGE

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
maxacc1=0
maxrs1=0
for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
    rfc=RandomForestClassifier()
    rfc.fit(x1_train,y1_train)
    pred1=rfc.predict(x1_test)
    acc1=accuracy_score(y1_test,pred1)
    if acc1>maxacc1:
        maxacc1=acc1
        maxrs1=i
print('best accuracy is',maxacc1,'at random state',maxrs1)
# Out:
# best accuracy is 0.9943491816056118 at random state 139

# %%
from sklearn.ensemble import RandomForestClassifier , ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier , AdaBoostClassifier , BaggingClassifier
from sklearn.metrics import classification_report , confusion_matrix , roc_curve , accuracy_score
from sklearn.model_selection import cross_val_score

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=139)
rfc=RandomForestClassifier()
rfc.fit(x1_train,y1_train)
predrfc1=rfc.predict(x1_test)
accurfc1=accuracy_score(y1_test,predrfc1)
print('accuracy score',accurfc1)
print('confusion matrix',confusion_matrix(y1_test,predrfc1))
print('classification report',classification_report(y1_test,predrfc1))
# Out:
# accuracy score 0.9937646141855028
# confusion matrix [[1243    2    1    0]
#  [   2 1273   10    1]
#  [   1    4 1290    3]
#  [   0    1    7 1294]]
# classification report               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1246
#            2       0.99      0.99      0.99      1286
#            3       0.99      0.99      0.99      1298
#            4       1.00      0.99      1.00      1302
#
#     accuracy                           0.99      5132
#    macro avg       0.99      0.99      0.99      5132
# weighted avg       0.99      0.99      0.99      5132

# %%
lr=LogisticRegression()
lr.fit(x1_train,y1_train)
predlr1=lr.predict(x1_test)
print('accuracy score',accuracy_score(y1_test,predlr1))
print('confusion matrix',confusion_matrix(y1_test,predlr1))
print('classification report',classification_report(y1_test,predlr1))
# Out:
# accuracy score 0.24279033515198753
# confusion matrix [[1246    0    0    0]
#  [1286    0    0    0]
#  [1298    0    0    0]
#  [1302    0    0    0]]
# classification report               precision    recall  f1-score   support
#
#            1       0.24      1.00      0.39      1246
#            2       0.00      0.00      0.00      1286
#            3       0.00      0.00      0.00      1298
#            4       0.00      0.00      0.00      1302
#
#     accuracy                           0.24      5132
#    macro avg       0.06      0.25      0.10      5132
# weighted avg       0.06      0.24      0.09      5132

# %%
svc=SVC()
svc.fit(x1_train,y1_train)
predsvc1=svc.predict(x1_test)
print(accuracy_score(y1_test,predsvc1))
print(confusion_matrix(y1_test,predsvc1))
print(classification_report(y1_test,predsvc1))
# Out:
# 0.31488698363211226
# [[634   0   0 612]
#  [535   0   0 751]
#  [439   0   0 859]
#  [320   0   0 982]]
#               precision    recall  f1-score   support
#
#            1       0.33      0.51      0.40      1246
#            2       0.00      0.00      0.00      1286
#            3       0.00      0.00      0.00      1298
#            4       0.31      0.75      0.44      1302
#
#     accuracy                           0.31      5132
#    macro avg       0.16      0.32      0.21      5132
# weighted avg       0.16      0.31      0.21      5132

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x1_train,y1_train)
predgbc1=gbc.predict(x1_test)
print(accuracy_score(y1_test,predgbc1))
print(confusion_matrix(y1_test,predgbc1))
print(classification_report(y1_test,predgbc1))
# Out:
# 0.9859703819173812
# [[1246    0    0    0]
#  [   9 1267    9    1]
#  [   0   22 1270    6]
#  [   0    2   23 1277]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1246
#            2       0.98      0.99      0.98      1286
#            3       0.98      0.98      0.98      1298
#            4       0.99      0.98      0.99      1302
#
#     accuracy                           0.99      5132
#    macro avg       0.99      0.99      0.99      5132
# weighted avg       0.99      0.99      0.99      5132

# %%
abc=AdaBoostClassifier()
abc.fit(x1_train,y1_train)
predabc1=abc.predict(x1_test)
print(accuracy_score(y1_test,predabc1))
print(confusion_matrix(y1_test,predabc1))
print(classification_report(y1_test,predabc1))
# Out:
# 0.6630943102104443
# [[1245    1    0    0]
#  [  21  782  481    2]
#  [   0  128 1152   18]
#  [   0    2 1076  224]]
#               precision    recall  f1-score   support
#
#            1       0.98      1.00      0.99      1246
#            2       0.86      0.61      0.71      1286
#            3       0.43      0.89      0.57      1298
#            4       0.92      0.17      0.29      1302
#
#     accuracy                           0.66      5132
#    macro avg       0.80      0.67      0.64      5132
# weighted avg       0.79      0.66      0.64      5132

# %%
bc=BaggingClassifier()
bc.fit(x1_train,y1_train)
predbc1=bc.predict(x1_test)
print(accuracy_score(y1_test,predbc1))
print(confusion_matrix(y1_test,predbc1))
print(classification_report(y1_test,predbc1))
# Out:
# 0.9920109119251753
# [[1242    4    0    0]
#  [   4 1277    4    1]
#  [   0    1 1293    4]
#  [   0    1   22 1279]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1246
#            2       1.00      0.99      0.99      1286
#            3       0.98      1.00      0.99      1298
#            4       1.00      0.98      0.99      1302
#
#     accuracy                           0.99      5132
#    macro avg       0.99      0.99      0.99      5132
# weighted avg       0.99      0.99      0.99      5132

# %%
etc= ExtraTreesClassifier()
etc.fit(x1_train,y1_train)
predetc1=etc.predict(x1_test)
print(accuracy_score(y1_test,predetc1))
print(confusion_matrix(y1_test,predetc1))
print(classification_report(y1_test,predetc1))
# Out:
# 0.9861652377240842
# [[1233   12    1    0]
#  [   6 1254   24    2]
#  [   1   11 1283    3]
#  [   0    2    9 1291]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1246
#            2       0.98      0.98      0.98      1286
#            3       0.97      0.99      0.98      1298
#            4       1.00      0.99      0.99      1302
#
#     accuracy                           0.99      5132
#    macro avg       0.99      0.99      0.99      5132
# weighted avg       0.99      0.99      0.99      5132

# %%
from sklearn.model_selection import cross_val_score
cvs=cross_val_score
rfcscore1=cvs(rfc,x1,y1)
print(rfcscore1)
print(rfcscore1.mean())
print('difference b/w accuracy score and cross val score',accuracy_score(y1_test,predrfc1)-rfcscore1.mean())
# Out:
# [0.82052032 0.99123063 0.99649225 0.98421514 0.98918129]
# 0.956327926412543
# difference b/w accuracy score and cross val score 0.03743668777295972

# %%
lrscore1=cvs(lr,x1,y1)
print(lrscore1)
print(lrscore1.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y1_test,predlr1)-lrscore1.mean())
# Out:
# [0.24992692 0.25021923 0.24992692 0.24992692 0.25      ]
# 0.25
# differnce b/w accuracy score and cross val score -0.00720966484801247

# %%
svcscore1=cvs(svc,x1,y1)
print(svcscore1)
print(svcscore1.mean())
print('difference b/w accuracy score and cross val score',accuracy_score(y1_test,predsvc1)-svcscore1.mean())
# Out:
# [0.32183572 0.30605086 0.32300497 0.3142356  0.34736842]
# 0.3224991153710057
# difference b/w accuracy score and cross val score -0.007612131738893413

# %%
gbcscore1=cvs(gbc,x1,y1)
print(gbcscore1)
print(gbcscore1.mean())
print('difference b/w accuracy score and cross val score',accuracy_score(y1_test,predgbc1)-gbcscore1.mean())
# Out:
# [0.92604502 0.98538439 0.9903537  0.97573809 0.97953216]
# 0.9714106712752846
# difference b/w accuracy score and cross val score 0.014559710642096602

# %%
abcscore1=cvs(abc,x1,y1)
print(abcscore1)
print(abcscore1.mean())
print('difference b/w accuracy score and cross val score',accuracy_score(y1_test,predabc1)-abcscore1.mean())
# Out:
# [0.51885414 0.68897983 0.76995031 0.74890383 0.7502924 ]
# 0.6953961001109418
# difference b/w accuracy score and cross val score -0.03230178990049748

# %%
bcscore1=cvs(bc,x1,y1)
print(bcscore1)
print(bcscore1.mean())
print('difference b/w accuracy score and cross val score',accuracy_score(y1_test,predbc1)-bcscore1.mean())
# Out:
# [0.80298158 0.99181526 0.99590763 0.98392283 0.9874269 ]
# 0.9524108405086574
# difference b/w accuracy score and cross val score 0.03960007141651789

# %%
etcscore1=cvs(etc,x1,y1)
print(etcscore1)
print(etcscore1.mean())
print('difference b/w accuracy score and cross val score',accuracy_score(y1_test,predetc1)-etcscore1.mean())
# Out:
# [0.81701257 0.96989184 0.96550716 0.97866121 0.95321637]
# 0.9368578320008343
# difference b/w accuracy score and cross val score 0.049307405723249875

# %%
#                                                 rfc       lr      svc       gbc      abc      bc     etc
# accuracy score(%)                              99.37    24.27    31.48     98.59   66.30    99.20    98.61    
# cvs score(%)                                   95.63    25.00    32.24     97.14   69.53    95.24    93.68
# difference b/w accuracy score and cvs score    0.037   -0.007   -0.007     0.014  -0.032    0.039    0.049

# %%
# 1) best model comes out to be gbc as the accuracy score is 98.59 and cvs score is 97.14 and difference is 0.014
#    it's accuracy is high (4th highest) and cvs score is also highest and difference b/w accuracy score and 
#    cvs score is lowest(it is a good model because accuracy and cvs score are high)
# 2) other best model can be rfc , bc , etc
#    2nd best model is rfc as it's accuracy is highest and cvs score is also 2nd highest and difference is also low 
#    similarly 3rd best model is bc and 4th best model is etc
# 3) model is build good there are less errors and the prediction is good as well

# %% [markdown]
# # SAVING THE MODEL AND LOADING THE MODEL AND PREDICTING BASED ON THE MODEL

# %%
import joblib
joblib.dump(gbc,'Zomato Restaurant price range prediction')
# Out:
# ['Zomato Restaurant price range prediction']

# %%
model=joblib.load('Zomato Restaurant price range prediction')
prediction=model.predict(x1_test)
prediction
# prediction for x1_test
# predicted label
# Out:
# array([2, 3, 3, ..., 3, 3, 2], dtype=int64)

# %%
y1_test
# Out:
# 4474     2
# 13604    4
# 12946    3
# 11312    3
# 11828    3
#         ..
# 8571     4
# 6607     2
# 10567    3
# 5219     3
# 1954     2
# Name: Price range, Length: 5132, dtype: int64

# %%
# we can see that almost all values are matching as accuracy score is high

# %%
x1_test
# these are the features used for prediction
# Out:
#        Restaurant ID  Country Code       City    Locality  Locality Verbose  \
# 4474          313206             1  87.000000  625.000000        626.000000
# 13604        3512676             1  40.321891  774.735259        774.482383
# 12946       18014446             1  84.629225  307.692250        311.200998
# 11312         310746             1  87.000000   84.620355         83.708799
# 11828         313052             1  49.000000  252.957540        252.957540
# ...              ...           ...        ...         ...               ...
# 8571         6202039           166  37.000000  102.000000        100.000000
# 6607        18352214             1  87.000000  990.000000       1027.000000
# 10567       18344117             1  66.771984  194.547810        193.120448
# 5219            1903             1  87.000000  707.000000        706.000000
# 1954            7249             1  87.000000   45.000000         45.000000
#
# ...
